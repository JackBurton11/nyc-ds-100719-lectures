# %%
import requests

# %%
import pandas as pd

df = pd.read_excel ('/Users/chrisshaw/Downloads/rollingsales_brooklyn.xls') 
df.head(10)
# Out:
#   Brooklyn Rolling Sales File.  All Sales From  Oct 2018 - Sep 2019  \
# 0  For sales prior to the Final, Neighborhood Nam...
# 1  Building Class Category is based on Building C...
# 2  Note: Condominium and cooperative sales are on...
# 3                                            BOROUGH
# 4                                                  3
# 5                                                  3
# 6                                                  3
# 7                                                  3
# 8                                                  3
# 9                                                  3
#
#      Unnamed: 1               Unnamed: 2            Unnamed: 3 Unnamed: 4  \
# 0           NaN                      NaN                   NaN        NaN
# 1           NaN                      NaN                   NaN        NaN
# 2           NaN                      NaN                   NaN        NaN
# ...

# %%
sales = df['Sales as of 10/15/2019']

# %%
len(df)
# Out:
# 23620

# %%
sales.value_counts()
# Out:
# 0            8220
# 10            291
# 1,200,000     136
# 650,000       129
# 1,100,000     129
#              ...
# 383,334         1
# 422,000         1
# 2,902,000       1
# 629,900         1
# 2,035,000       1
# Name: Sales as of 10/15/2019, Length: 3308, dtype: int64
